# %%
# インポート
from sources.api.bus import *
from sources.api.train import *
# Out:
# /Users/x0y14/dev/reachable-area/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# データの読み込み
stops = load_stop_data("../dataset/busstpos/kanagawa/P11-22_14.geojson")
stations = load_station_data("../dataset/stations/N02-20_Station.geojson")

# %%
# 神奈川中央交通の、KAITを通るバス停のみを取り出す。
kait_stops = []
kait_routes = ['厚07', '厚67', '厚89']  # 神奈川工科大学に辿り着けるバス路線
for stop in stops:
    for kait_route in kait_routes:
        if (kait_route in stop.routes) and (stop not in kait_stops):
            kait_stops.append(stop)

# 小田原線の駅のみ取り出す。
odakyu_stations = []
for station in stations:
    if "小田原線" == station.line:
        odakyu_stations.append(station)

print(f"神奈川中央交通のバス停: {len(kait_stops)}, 小田原線の駅: {len(odakyu_stations)}")
# Out:
# 神奈川中央交通のバス停: 30, 小田原線の駅: 47

# %%
# >> 不動産公正取引協議会連合会が定める「不動産の表示に関する公正競争規約」では、徒歩で１分間に歩く距離を「80m」として所要時間が算出されています。(出典: https://www.ur-net.go.jp/chintai/college/202310/000877.html, 2024/08/06 閲覧)

# 各バス停から800メートル以内の駅を取り出す。
stations800m = []
for station in odakyu_stations:
    station_mean_coord = station.geometry.calc_mean()
    for stop in kait_stops:
        distance_between_station_and_stop = calc_distance_m(station_mean_coord, stop.geometry.calc_mean())
        if (distance_between_station_and_stop <= 800) and station not in stations800m:
            stations800m.append(station)
print(f"いずれかのバス停から800m以内に存在する小田急の駅の数: {len(stations800m)}")
for st in stations800m:
    print(st.name)
# Out:
# いずれかのバス停から800m以内に存在する小田急の駅の数: 1
# 本厚木

# %%
# kait経路のバス停から10分県内のバス停を取得する(緯度経度による簡易的な距離計算)
stops_within_800m_from_kait_route_stops = {}
for stop in stops:
    for kait_stop in kait_stops:
        distance = calc_distance_m(stop.geometry.calc_mean(), kait_stop.geometry.calc_mean())
        if (distance <= 800) and (stop not in kait_stops):  # 既に路線内に組み込まれているバス停はスキップ
            stop_name = f"{', '.join(stop.group)}・{stop.name}"
            kait_stop_name = f"{', '.join(kait_stop.group)}・{kait_stop.name}"
            if stop_name in stops_within_800m_from_kait_route_stops:
                stops_within_800m_from_kait_route_stops[stop_name].append(
                    (f"{stop_name}", f"{kait_stop_name}", distance)
                )
            else:
                stops_within_800m_from_kait_route_stops[stop_name] = [
                    (f"{stop_name}", f"{kait_stop_name}", distance)
                ]

print(f"KAIT路線から10分圏内のバス停の数: {len(stops_within_800m_from_kait_route_stops)}")
for stop_name in stops_within_800m_from_kait_route_stops.keys():
    print(stops_within_800m_from_kait_route_stops[stop_name])
# Out:
# KAIT路線から10分圏内のバス停の数: 46
# [('愛川町・坂本', '神奈川中央交通（株）・下川入', 722.2279947903189), ('愛川町・坂本', '神奈川中央交通（株）・才戸橋', 685.3033389103202)]
# [('神奈川中央交通（株）・坂本', '神奈川中央交通（株）・下川入', 722.2279947903189), ('神奈川中央交通（株）・坂本', '神奈川中央交通（株）・才戸橋', 685.3033389103202)]
# [('神奈川中央交通（株）・荻野中学校入口', '神奈川中央交通（株）・鳶尾団地', 609.2506231631515)]
# [('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・下川入', 779.8822573674843), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・才戸橋', 705.6201373998452), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・あつぎ郷土博物館', 676.0824048622727), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・棚沢', 668.9819252249737), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・下谷', 527.0964773963263), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・西四ツ谷', 614.1375268514664), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・リコー前', 573.5090023750835), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・神奈川工科大学', 685.6291700873779), ('神奈川中央交通（株）・上三田', '神奈川中央交通（株）・神奈川工科大学前', 775.8099063275953)]
# [('神奈川中央交通（株）・荻野神社入口', '神奈川中央交通（株）・鳶尾団地', 414.7681937980461), ('神奈川中央交通（株）・荻野神社入口', '神奈川中央交通（株）・鳶尾小学校入口', 757.3984571400666)]
# [('神奈川中央交通（株）・鳶尾四丁目', '神奈川中央交通（株）・鳶尾一丁目', 773.913004404214), ('神奈川中央交通（株）・鳶尾四丁目', '神奈川中央交通（株）・鳶尾団地', 237.88432526377662), ('神奈川中央交通（株）・鳶尾四丁目', '神奈川中央交通（株）・鳶尾小学校入口', 555.6525837464197)]
# [('神奈川中央交通（株）・鳶尾山前', '神奈川中央交通（株）・鳶尾団地', 384.33554239417714), ('神奈川中央交通（株）・鳶尾山前', '神奈川中央交通（株）・鳶尾小学校入口', 647.8243461436382)]
# [('神奈川中央交通（株）・十軒村', '神奈川中央交通（株）・リコー前', 715.6467059461338), ('神奈川中央交通（株）・十軒村', '神奈川中央交通（株）・神奈川工科大学', 646.0513130834496), ('神奈川中央交通（株）・十軒村', '神奈川中央交通（株）・神奈川工科大学前', 646.304096558417)]
# [('神奈川中央交通（株）・稲荷木', '神奈川中央交通（株）・鳶尾団地', 556.4106887848005), ('神奈川中央交通（株）・稲荷木', '神奈川中央交通（株）・鳶尾小学校入口', 668.5558180141694)]
# [('神奈川中央交通（株）・うとう坂', '神奈川中央交通（株）・鳶尾団地', 719.951057181543)]
# [('神奈川中央交通（株）・公所', '神奈川中央交通（株）・鳶尾小学校入口', 761.8464117386028), ('神奈川中央交通（株）・公所', '神奈川中央交通（株）・鳶尾団地東', 763.6866791467212)]
# [('神奈川中央交通（株）・桝割', '神奈川中央交通（株）・鳶尾団地東', 774.1855095549845), ('神奈川中央交通（株）・桝割', '神奈川中央交通（株）・神奈川工科大学', 789.4020798218769), ('神奈川中央交通（株）・桝割', '神奈川中央交通（株）・神奈川工科大学前', 764.7709476187249)]
# [('神奈川中央交通（株）・子合', '神奈川中央交通（株）・神奈川工科大学', 707.8072609963398), ('神奈川中央交通（株）・子合', '神奈川中央交通（株）・神奈川工科大学前', 607.1803122989788), ('神奈川中央交通（株）・子合', '神奈川中央交通（株）・子中', 406.26621466206774), ('神奈川中央交通（株）・子合', '神奈川中央交通（株）・荻野新宿', 472.76902652002326)]
# [('神奈川中央交通（株）・山王坂下', '神奈川中央交通（株）・宿原入口', 703.3547389989021), ('神奈川中央交通（株）・山王坂下', '神奈川中央交通（株）・糀屋前', 686.3251572541271)]
# [('神奈川中央交通（株）・屋際', '神奈川中央交通（株）・糀屋前', 736.8333472615994)]
# [('神奈川中央交通（株）・山王坂上', '神奈川中央交通（株）・子中', 689.674372082187), ('神奈川中央交通（株）・山王坂上', '神奈川中央交通（株）・荻野新宿', 463.07558204784596), ('神奈川中央交通（株）・山王坂上', '神奈川中央交通（株）・宿原入口', 177.06739341343663), ('神奈川中央交通（株）・山王坂上', '神奈川中央交通（株）・糀屋前', 400.1755321952156)]
# [('神奈川中央交通（株）・小山', '神奈川中央交通（株）・荻野新宿', 585.7348372940056), ('神奈川中央交通（株）・小山', '神奈川中央交通（株）・宿原入口', 371.9059995839154), ('神奈川中央交通（株）・小山', '神奈川中央交通（株）・糀屋前', 512.7543999193849)]
# [('神奈川中央交通（株）・天台上野原', '神奈川中央交通（株）・荻野新宿', 790.924626391746), ('神奈川中央交通（株）・天台上野原', '神奈川中央交通（株）・宿原入口', 619.4451091541139), ('神奈川中央交通（株）・天台上野原', '神奈川中央交通（株）・糀屋前', 700.6490566250465)]
# [('神奈川中央交通（株）・及川富士塚', '神奈川中央交通（株）・宿原入口', 727.8872217391008), ('神奈川中央交通（株）・及川富士塚', '神奈川中央交通（株）・糀屋前', 716.9880217111224)]
# [('神奈川中央交通（株）・睦合東中学校入口', '神奈川中央交通（株）・妻田薬師', 438.60782303919706), ('神奈川中央交通（株）・睦合東中学校入口', '神奈川中央交通（株）・中村入口', 626.9398341649188)]
# [('神奈川中央交通（株）・及川球技場入口', '神奈川中央交通（株）・糀屋前', 672.9498436862762), ('神奈川中央交通（株）・及川球技場入口', '神奈川中央交通（株）・松蓮寺', 593.6556772528957)]
# [('神奈川中央交通（株）・そりだハイツ前', '神奈川中央交通（株）・妻田薬師', 383.66970381575794), ('神奈川中央交通（株）・そりだハイツ前', '神奈川中央交通（株）・中村入口', 327.31436119673583), ('神奈川中央交通（株）・そりだハイツ前', '神奈川中央交通（株）・妻田', 661.7534426725801), ('神奈川中央交通（株）・そりだハイツ前', '神奈川中央交通（株）・妻田', 670.9063173327128)]
# [('神奈川中央交通（株）・金田下宿', '神奈川中央交通（株）・妻田', 782.089879862987)]
# [('神奈川中央交通（株）・林中学校入口', '神奈川中央交通（株）・中村入口', 763.6058387145292), ('神奈川中央交通（株）・林中学校入口', '神奈川中央交通（株）・妻田', 772.1506351679028), ('神奈川中央交通（株）・林中学校入口', '神奈川中央交通（株）・妻田', 711.1869166545063)]
# [('神奈川中央交通（株）・戸室', '神奈川中央交通（株）・三家入口', 773.5910427849291)]
# [('神奈川中央交通（株）・吾妻団地', '神奈川中央交通（株）・妻田', 781.2304722041974), ('神奈川中央交通（株）・吾妻団地', '神奈川中央交通（株）・妻田', 743.432914915468), ('神奈川中央交通（株）・吾妻団地', '神奈川中央交通（株）・三家入口', 508.972615417738), ('神奈川中央交通（株）・吾妻団地', '神奈川中央交通（株）・木売場', 511.70844832889804), ('神奈川中央交通（株）・吾妻団地', '神奈川中央交通（株）・市立病院前', 721.5459784452079)]
# [('神奈川中央交通（株）・鮎津橋', '神奈川中央交通（株）・三家入口', 646.173160555468), ('神奈川中央交通（株）・鮎津橋', '神奈川中央交通（株）・木売場', 539.2835787061216), ('神奈川中央交通（株）・鮎津橋', '神奈川中央交通（株）・市立病院前', 551.4049029985493), ('神奈川中央交通（株）・鮎津橋', '神奈川中央交通（株）・税務署入口', 743.9548071980153)]
# [('神奈川中央交通（株）・愛光病院前', '神奈川中央交通（株）・三家入口', 534.3812674872925), ('神奈川中央交通（株）・愛光病院前', '神奈川中央交通（株）・木売場', 408.3674297348213), ('神奈川中央交通（株）・愛光病院前', '神奈川中央交通（株）・市立病院前', 477.7331588020043), ('神奈川中央交通（株）・愛光病院前', '神奈川中央交通（株）・税務署入口', 677.686350986392)]
# [('神奈川中央交通（株）・戸室神社下', '神奈川中央交通（株）・木売場', 769.9222948470659)]
# [('神奈川中央交通（株）・松枝町一丁目', '神奈川中央交通（株）・三家入口', 763.7321255274785), ('神奈川中央交通（株）・松枝町一丁目', '神奈川中央交通（株）・木売場', 539.1158664805661), ('神奈川中央交通（株）・松枝町一丁目', '神奈川中央交通（株）・市立病院前', 228.67932181784636), ('神奈川中央交通（株）・松枝町一丁目', '神奈川中央交通（株）・税務署入口', 285.7930883723173), ('神奈川中央交通（株）・松枝町一丁目', '神奈川中央交通（株）・市役所入口', 658.9165895351576), ('神奈川中央交通（株）・松枝町一丁目', '神奈川中央交通（株）・あつぎ大通り', 725.2348589971652)]
# [('神奈川中央交通（株）・戸室住宅前', '神奈川中央交通（株）・市立病院前', 693.6325726233441), ('神奈川中央交通（株）・戸室住宅前', '神奈川中央交通（株）・税務署入口', 715.8425740650404)]
# [('神奈川中央交通（株）・元町', '神奈川中央交通（株）・市立病院前', 566.2915057311857), ('神奈川中央交通（株）・元町', '神奈川中央交通（株）・税務署入口', 503.8077279311072), ('神奈川中央交通（株）・元町', '神奈川中央交通（株）・市役所入口', 693.0069509228267), ('神奈川中央交通（株）・元町', '神奈川中央交通（株）・あつぎ大通り', 705.5535802214662), ('神奈川中央交通（株）・元町', '神奈川中央交通（株）・厚木バスセンター', 661.7028538224741), ('神奈川中央交通（株）・元町', '神奈川中央交通（株）・本厚木駅', 773.6648209829413)]
# [('神奈川中央交通（株）・厚木警察署前', '神奈川中央交通（株）・木売場', 729.1637806126244), ('神奈川中央交通（株）・厚木警察署前', '神奈川中央交通（株）・市立病院前', 417.1507560662579), ('神奈川中央交通（株）・厚木警察署前', '神奈川中央交通（株）・税務署入口', 277.71298244362504), ('神奈川中央交通（株）・厚木警察署前', '神奈川中央交通（株）・市役所入口', 491.54731440473313), ('神奈川中央交通（株）・厚木警察署前', '神奈川中央交通（株）・あつぎ大通り', 608.576966936443)]
# [('神奈川中央交通（株）・厚木東町', '神奈川中央交通（株）・税務署入口', 757.8608540422465), ('神奈川中央交通（株）・厚木東町', '神奈川中央交通（株）・市役所入口', 760.0036933804918), ('神奈川中央交通（株）・厚木東町', '神奈川中央交通（株）・あつぎ大通り', 716.0661793179706), ('神奈川中央交通（株）・厚木東町', '神奈川中央交通（株）・厚木バスセンター', 461.1827008700705), ('神奈川中央交通（株）・厚木東町', '神奈川中央交通（株）・本厚木駅', 656.0892322554434)]
# [('神奈川中央交通（株）・合同庁舎前', '神奈川中央交通（株）・市立病院前', 683.3504600957261), ('神奈川中央交通（株）・合同庁舎前', '神奈川中央交通（株）・税務署入口', 493.6716702266965), ('神奈川中央交通（株）・合同庁舎前', '神奈川中央交通（株）・市役所入口', 477.75250215368237), ('神奈川中央交通（株）・合同庁舎前', '神奈川中央交通（株）・あつぎ大通り', 587.6982572061726)]
# [('神奈川中央交通（株）・中央通り', '神奈川中央交通（株）・税務署入口', 683.9542542611221), ('神奈川中央交通（株）・中央通り', '神奈川中央交通（株）・市役所入口', 604.7900001729533), ('神奈川中央交通（株）・中央通り', '神奈川中央交通（株）・あつぎ大通り', 547.8058130297817), ('神奈川中央交通（株）・中央通り', '神奈川中央交通（株）・厚木バスセンター', 291.5338926223401), ('神奈川中央交通（株）・中央通り', '神奈川中央交通（株）・本厚木駅', 475.6175524206444)]
# [('神奈川中央交通（株）・小田急通り', '神奈川中央交通（株）・市立病院前', 781.6787775500661), ('神奈川中央交通（株）・小田急通り', '神奈川中央交通（株）・税務署入口', 557.178708166045), ('神奈川中央交通（株）・小田急通り', '神奈川中央交通（株）・市役所入口', 458.6866242604764), ('神奈川中央交通（株）・小田急通り', '神奈川中央交通（株）・あつぎ大通り', 410.8902654049152), ('神奈川中央交通（株）・小田急通り', '神奈川中央交通（株）・厚木バスセンター', 278.7834864960157), ('神奈川中央交通（株）・小田急通り', '神奈川中央交通（株）・本厚木駅', 393.4824145512526)]
# [('神奈川中央交通（株）・天王町', '神奈川中央交通（株）・市役所入口', 778.1503215374324), ('神奈川中央交通（株）・天王町', '神奈川中央交通（株）・あつぎ大通り', 695.2200977457372), ('神奈川中央交通（株）・天王町', '神奈川中央交通（株）・厚木バスセンター', 300.65030916227323), ('神奈川中央交通（株）・天王町', '神奈川中央交通（株）・本厚木駅', 531.392966675418)]
# [('神奈川中央交通（株）・仲町', '神奈川中央交通（株）・あつぎ大通り', 750.6899439729932), ('神奈川中央交通（株）・仲町', '神奈川中央交通（株）・厚木バスセンター', 325.60118099951904), ('神奈川中央交通（株）・仲町', '神奈川中央交通（株）・本厚木駅', 541.1640535616413)]
# [('神奈川中央交通西（株）, 京浜急行バス（株）・本厚木駅北口', '神奈川中央交通（株）・税務署入口', 737.7462613001326), ('神奈川中央交通西（株）, 京浜急行バス（株）・本厚木駅北口', '神奈川中央交通（株）・市役所入口', 332.709673309684), ('神奈川中央交通西（株）, 京浜急行バス（株）・本厚木駅北口', '神奈川中央交通（株）・あつぎ大通り', 223.3263362534486), ('神奈川中央交通西（株）, 京浜急行バス（株）・本厚木駅北口', '神奈川中央交通（株）・厚木バスセンター', 375.7718147133782), ('神奈川中央交通西（株）, 京浜急行バス（株）・本厚木駅北口', '神奈川中央交通（株）・本厚木駅', 145.19648551330783)]
# [('神奈川中央交通（株）・栄町二丁目', '神奈川中央交通（株）・市役所入口', 596.5657201525116), ('神奈川中央交通（株）・栄町二丁目', '神奈川中央交通（株）・あつぎ大通り', 640.1719516327784)]
# [('神奈川中央交通（株）・本厚木駅南口', '神奈川中央交通（株）・市役所入口', 479.798193365926), ('神奈川中央交通（株）・本厚木駅南口', '神奈川中央交通（株）・あつぎ大通り', 362.00602376980606), ('神奈川中央交通（株）・本厚木駅南口', '神奈川中央交通（株）・厚木バスセンター', 266.1969553369616), ('神奈川中央交通（株）・本厚木駅南口', '神奈川中央交通（株）・本厚木駅', 111.45671229931949)]
# [('神奈川中央交通（株）・中町四丁目', '神奈川中央交通（株）・市役所入口', 469.37897518399507), ('神奈川中央交通（株）・中町四丁目', '神奈川中央交通（株）・あつぎ大通り', 388.43798318142586), ('神奈川中央交通（株）・中町四丁目', '神奈川中央交通（株）・厚木バスセンター', 562.8689830593404), ('神奈川中央交通（株）・中町四丁目', '神奈川中央交通（株）・本厚木駅', 338.6147992304399)]
# [('神奈川中央交通（株）・旭町', '神奈川中央交通（株）・厚木バスセンター', 474.40083225741495), ('神奈川中央交通（株）・旭町', '神奈川中央交通（株）・本厚木駅', 577.5009469410461)]
# [('神奈川中央交通（株）・旭町一丁目', '神奈川中央交通（株）・市役所入口', 638.4012058486474), ('神奈川中央交通（株）・旭町一丁目', '神奈川中央交通（株）・あつぎ大通り', 542.1454253987171), ('神奈川中央交通（株）・旭町一丁目', '神奈川中央交通（株）・厚木バスセンター', 585.8578021040222), ('神奈川中央交通（株）・旭町一丁目', '神奈川中央交通（株）・本厚木駅', 401.1664730300633)]
# [('神奈川中央交通（株）・下宿', '神奈川中央交通（株）・厚木バスセンター', 686.315419629342), ('神奈川中央交通（株）・下宿', '神奈川中央交通（株）・本厚木駅', 656.6042714153542)]
