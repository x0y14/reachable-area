# %% [markdown]
# ## 交通手段を用いた移動時間と徒歩の時間を考慮する

# %% [markdown]
# ### 同じ路線のみ, 指定の時間以下で辿り着けるバス停を表示

# %%
from typing import Optional

from engine import Station, TransitType, get_route_yahoo_transit
from engine.bus import *
from engine.train import *

# データの読み込み
dataset: dict[TransitType, list[Station]] = {
    TransitType.BUS: load_stop_data("../dataset/busstops/kanagawa/P11-22_14.geojson"),
    TransitType.TRAIN: load_station_data("../dataset/stations/N02-20_Station.geojson"),
}


def _include(a: list[str], b: list[str]) -> bool:
    for a_content in a:
        if a_content in b:
            return True
    return False


def get_same_line_route_stations(station: Station) -> list[Station]:
    stations: list[Station] = []

    if station.transit_type == TransitType.BUS:
        for stop in dataset[TransitType.BUS]:
            if (
                    (stop.management_groups == station.management_groups)
                    and (_include(station.line_routes, stop.line_routes))
                    and (stop.name != station.name)
            ):
                stations.append(stop)
    elif station.transit_type == TransitType.TRAIN:
        for stat in dataset[TransitType.TRAIN]:
            if (stat.line_routes == station.line_routes) and (
                    stat.name != station.name
            ):
                stations.append(stat)

    return stations

def get_stations_with_time(from_: Station, limit_min: int) -> list[tuple[Station, int]]:
    stations: list[tuple[Station, int]] = []
    same_line_stations = get_same_line_route_stations(from_)
    transit_type = from_.transit_type
    
    for same_line_station in same_line_stations:
        will_add = False
        min_time_required = -1
        routes = get_route_yahoo_transit(transit_type, from_, same_line_station)
        # routeをすべてチェックする
        for route in routes:
            if (route["transfer"] == 0) and route["time_required"] <= limit_min:
                will_add = True
            # 最低所要時間を更新する
            if min_time_required == -1:
                min_time_required = route["time_required"]
            else:
                if route["time_required"] < min_time_required:
                    min_time_required = route["time_required"]
        if will_add:
            stations.append((same_line_station, min_time_required))
    
    return stations
# Out:
# 10分: 松蓮寺
# 9分: 及川球技場入口
# 10分: 千頭
# 9分: 及川
# 9分: 妻田薬師
# 10分: そりだハイツ前
# 8分: 中村入口
# 8分: 穴口橋
# 6分: 妻田
# 6分: 妻田
# 7分: 林中学校入口
# 7分: 林
# 6分: 三家入口
# 6分: 戸室
# 10分: 緑ヶ丘小学校前
# 10分: 白山
# 6分: 吾妻団地
# 9分: 緑ヶ丘中央
# 5分: 木売場
# 9分: 小金
# 5分: 愛光病院前
# 5分: 戸室神社下
# 8分: 黄金原
# 4分: 市立病院前
# 3分: 松枝町一丁目
# 4分: 戸室住宅前
# 6分: アンリツ前
# 3分: 税務署入口
# 4分: 厚木警察署前
# 1分: 厚木東町
# 4分: 厚木高校前
# 1分: 小田急通り
# 1分: あつぎ大通り
# 2分: 厚木バスセンター
# 7分: 温水
# 3分: 栄町二丁目
# 8分: 温水児童館前
# 8分: 温水児童館前
# 4分: 恩名公民館前
# 8分: 高坪入口
# 7分: 恩名下
# 6分: 赤羽根中央
# 6分: 厚木市文化会館前
# 5分: 赤羽根入口

# %% [markdown]
# ### 同じ路線のみ, 指定の時間以下で辿り着けるバス停, およびその周辺の徒歩エリア

# %%
from typing import Optional
from engine import Station, TransitType, get_route_yahoo_transit
from engine.bus import *
from engine.train import *

# データの読み込み
dataset: dict[TransitType, list[Station]] = {
    TransitType.BUS: load_stop_data("../dataset/busstops/kanagawa/P11-22_14.geojson"),
    TransitType.TRAIN: load_station_data("../dataset/stations/N02-20_Station.geojson"),
}


def _include(a: list[str], b: list[str]) -> bool:
    for a_content in a:
        if a_content in b:
            return True
    return False


def get_same_line_route_stations(station: Station) -> list[Station]:
    stations: list[Station] = []

    if station.transit_type == TransitType.BUS:
        for stop in dataset[TransitType.BUS]:
            if (
                    (stop.management_groups == station.management_groups)
                    and (_include(station.line_routes, stop.line_routes))
                    and (stop.name != station.name)
            ):
                stations.append(stop)
    elif station.transit_type == TransitType.TRAIN:
        for stat in dataset[TransitType.TRAIN]:
            if (stat.line_routes == station.line_routes) and (
                    stat.name != station.name
            ):
                stations.append(stat)

    return stations

def get_stations_with_time(from_: Station, limit_min: int) -> list[tuple[Station, int]]:
    stations: list[tuple[Station, int]] = []
    same_line_stations = get_same_line_route_stations(from_)
    transit_type = from_.transit_type

    for same_line_station in same_line_stations:
        will_add = False
        min_time_required = -1
        routes = get_route_yahoo_transit(transit_type, from_, same_line_station)
        # routeをすべてチェックする
        for route in routes:
            if (route["transfer"] == 0) and route["time_required"] <= limit_min:
                will_add = True
            # 最低所要時間を更新する
            if min_time_required == -1:
                min_time_required = route["time_required"]
            else:
                if route["time_required"] < min_time_required:
                    min_time_required = route["time_required"]
        if will_add:
            stations.append((same_line_station, min_time_required))

    return stations

# バスの本厚木駅を取り出す
honatugi_bus_stop: Optional[Station] = None
for stop in dataset[TransitType.BUS]:
    if stop.name == "本厚木駅":
        honatugi_bus_stop = stop
if honatugi_bus_stop is None:
    print("本厚木駅をみつけられませんでした")

# %%
from typing import Any
import geopandas
from geopandas import GeoSeries
from shapely.ops import unary_union

def concat_isochrones_per_contour(isochrones: list[dict[Any, Any]]) -> dict[int, dict]:
    result: dict[int, dict[Any, Any]] = {}  # int -> time_contour -> ["features"]["properties"]["contour"]
    for feature_collection in isochrones:
        gdf = geopandas.GeoDataFrame.from_features(feature_collection)
        for feature in gdf.iterfeatures():
            contour = feature["properties"]["contour"]
            # init
            if contour not in result:
                result[contour] = feature
            else:
                result[contour] = geopandas.GeoSeries(unary_union([result[contour], feature])).to_dict()
  
    return result

def concat_isochrones(isochrones: list[dict[Any, Any]]) -> geopandas.GeoSeries:
    gdf_geometries = []
    for feature_collection in isochrones:
        gdf = geopandas.GeoDataFrame.from_features(feature_collection)
        for gdf_geometry in gdf.geometry:
            gdf_geometries.append(gdf_geometry)
    return geopandas.GeoSeries(unary_union(gdf_geometries))

# %%
import folium
import os
from dotenv import load_dotenv
from engine.mapbox import MapBoxApi, IsochroneProfile

load_dotenv()
api = MapBoxApi(os.getenv("MAPBOX_API_TOKEN"))

m = folium.Map(
    location=[35.4861002, 139.3399782],
    zoom_start=14,
    tiles="https://cyberjapandata.gsi.go.jp/xyz/std/{z}/{x}/{y}.png",
    attr=f"出典: 国土地理院ウェブサイト・地理院タイル・標準地図 {'(C) MAPBOX'}",
)

max_min = 10

# バスの本厚木駅を取り出す
honatugi_bus_stop: Optional[Station] = None
for stop in dataset[TransitType.BUS]:
    if stop.name == "本厚木駅":
        honatugi_bus_stop = stop
if honatugi_bus_stop is None:
    print("本厚木駅をみつけられませんでした")

busstops_can_reach_in_10mins = get_stations_with_time(honatugi_bus_stop, max_min)
# for stat, time_req in res: # type: # Station,int
#     print(f"{time_req}分: {stat.name}")

near_isochrones = []

for near_station, time_req in busstops_can_reach_in_10mins: # type: Station,int
    contour = max_min - time_req
    if contour < 1: # API側に1 <= contur <= 60の制限がある
        contour = 1
    if 60 < contour:
        contour = 60
    isochrone_feature_collection = api.get_isochrone(
        prof=IsochroneProfile.Walking,
        coordinate=near_station.geometry.calc_mean(),
        contours_minutes=[contour]
    )
    near_isochrones.append(isochrone_feature_collection)
    
    folium.Marker(
        location=near_station.geometry.calc_mean().to_folium(),
        popup=near_station.name,
        icon=folium.Icon(color='blue')
    ).add_to(m)

area_10mins_walking_and_bus = concat_isochrones(near_isochrones)

folium.GeoJson(area_10mins_walking_and_bus.to_json()).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c7f81d3af9c1d19a886c1747bd8af50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c7f81d3af9c1d19a886c1747bd8af50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c7f81d3af9c1d19a886c1747bd8af50 = L.map(
#                 &quot;map_8c7f81d3af9c1d19a886c1747bd8af50&quot;,
#                 {
#                     center: [35.4861002, 139.3399782],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66877d23363cd0341e37a5a6275bde79 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/std/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u51fa\u5178: \u56fd\u571f\u5730\u7406\u9662\u30a6\u30a7\u30d6\u30b5\u30a4\u30c8\u30fb\u5730\u7406\u9662\u30bf\u30a4\u30eb\u30fb\u6a19\u6e96\u5730\u56f3 (C) MAPBOX&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_66877d23363cd0341e37a5a6275bde79.addTo(map_8c7f81d3af9c1d19a886c1747bd8af50);
#
#
#             var marker_41e8fea0afe42a891b96efb3971bc9dd = L.marker(
#                 [35.46952843837568, 139.34961486418683],
#                 {}
#             ).addTo(map_8c7f81d3af9c1d19a886c1747bd8af50);
#
#
#             var icon_51b9806e2307d689b0a8d419ec7a8c2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_41e8fea0afe42a891b96efb3971bc9dd.setIcon(icon_51b9806e2307d689b0a8d419ec7a8c2b);
#
#
#         var popup_342fa5748b6ddf761a6d54fa1bd22aac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_009418523416e687ee38db7add8e5776 = $(`&lt;div id=&quot;html_009418523416e687ee38db7add8e5776&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;松蓮寺&lt;/div&gt;`)[0];
#                 popup_342fa5748b6ddf761a6d54fa1bd22aac.setContent(html_009418523416e687ee38db7add8e5776);
#
#
#
#         marker_41e8fea0afe42a891b96efb3971bc9dd.bindPopup(popup_342fa5748b6ddf761a6d54fa1bd22aac)
#         ;
#
#
#
#
#             var marker_0489383315922ac45fee3efafe9b9643 = L.marker(
#                 [35.46713901100272, 139.34376266750178],
#                 {}
#             ).addTo(map_8c7f81d3af9c1d19a886c1747bd8af50);
#
#
#             var icon_ece3807787a3131bc94caa871178059f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0489383315922ac45fee3efafe9b9643.setIcon(icon_ece3807787a3131bc94caa871178059f);
#
#
#         var popup_326d1ed31676ad18548d8877b3eca3c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b235cbb773ad810c868a09979179208e = $(`&lt;div id=&quot;html_b235cbb773ad810c868a09979179208e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;及川球技場入口&lt;/div&gt;`)[0];
#                 popup_326d1ed31676ad18548d8877b3eca3c3.setContent(html_b235cbb773ad810c868a09979179208e);
#
#
#
#         marker_0489383315922ac45fee3efafe9b9643.bindPopup(popup_326d1ed31676ad18548d8877b3eca3c3)
#         ;
#
#
#
#
#             var marker_1793ebb650f9d81e1da2291635c3c176 = L.marker(
#                 [35.466268299182296, 139.33758237962357],
#                 {}
#             ).addTo(map_8c7f81d3af9c1d19a886c1747bd8af50);
#
#
#             var icon_364696eb1604cad11eea30df35ac87b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1793ebb650f9d81e1da2291635c3c176.setIcon(icon_364696eb1604cad11eea30df35ac87b5);
#
#
#         var popup_e60757974dfd8b8962877e2002dceefd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26a1c7a25eebab53df7112adb38d8d48 = $(`&lt;div id=&quot;html_26a1c7a25eebab53df7112adb38d8d48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;千頭&lt;/div&gt;`)[0];
#                 popup_e60757974dfd8b8962877e2002dceefd.setContent(html_26a1c7a25eebab53df7112adb38d8d48);
#
#
#
#         marker_1793ebb650f9d81e1da2291635c3c176.bindPopup(popup_e60757974dfd8b8962877e2002dceefd)
#         ;
#
#
#
#
#             var marker_988b81bffc139da6af71b281210925e2 = L.marker(
#                 [35.46514473539581, 139.3422939402889],
#                 {}
#             ).addTo(map_8c7f81d3af9c1d19a886c1747bd8af50);
#
#
#             var icon_1ad90b995f901efe7974d1cc440db279 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;i

# %%
import folium
import os
from dotenv import load_dotenv
from engine.mapbox import MapBoxApi, IsochroneProfile

load_dotenv()
api = MapBoxApi(os.getenv("MAPBOX_API_TOKEN"))

m = folium.Map(
    location=[35.4861002, 139.3399782],
    zoom_start=14,
    tiles="https://cyberjapandata.gsi.go.jp/xyz/std/{z}/{x}/{y}.png",
    attr=f"出典: 国土地理院ウェブサイト・地理院タイル・標準地図 {'(C) MAPBOX'}",
)

max_min = 20

# バスの本厚木駅を取り出す
honatugi_bus_stop: Optional[Station] = None
for stop in dataset[TransitType.BUS]:
    if stop.name == "本厚木駅":
        honatugi_bus_stop = stop
if honatugi_bus_stop is None:
    print("本厚木駅をみつけられませんでした")

busstops_can_reach_in_10mins = get_stations_with_time(honatugi_bus_stop, max_min)
# for stat, time_req in res: # type: # Station,int
#     print(f"{time_req}分: {stat.name}")

near_isochrones = []

for near_station, time_req in busstops_can_reach_in_10mins: # type: Station,int
    contour = max_min - time_req
    if contour < 1: # API側に1 <= contur <= 60の制限がある
        contour = 1
    if 60 < contour:
        contour = 60
    isochrone_feature_collection = api.get_isochrone(
        prof=IsochroneProfile.Walking,
        coordinate=near_station.geometry.calc_mean(),
        contours_minutes=[contour]
    )
    near_isochrones.append(isochrone_feature_collection)

    folium.Marker(
        location=near_station.geometry.calc_mean().to_folium(),
        popup=near_station.name,
        icon=folium.Icon(color='blue')
    ).add_to(m)

area_10mins_walking_and_bus = concat_isochrones(near_isochrones)

folium.GeoJson(area_10mins_walking_and_bus.to_json()).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1ff0a4275f87aa22174214f407e0632 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1ff0a4275f87aa22174214f407e0632&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1ff0a4275f87aa22174214f407e0632 = L.map(
#                 &quot;map_d1ff0a4275f87aa22174214f407e0632&quot;,
#                 {
#                     center: [35.4861002, 139.3399782],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56e383238a523e28b659a13a0c49b4df = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/std/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u51fa\u5178: \u56fd\u571f\u5730\u7406\u9662\u30a6\u30a7\u30d6\u30b5\u30a4\u30c8\u30fb\u5730\u7406\u9662\u30bf\u30a4\u30eb\u30fb\u6a19\u6e96\u5730\u56f3 (C) MAPBOX&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_56e383238a523e28b659a13a0c49b4df.addTo(map_d1ff0a4275f87aa22174214f407e0632);
#
#
#             var marker_3eac4957ce6f10dda577e427a0f5df6d = L.marker(
#                 [35.497950457559874, 139.34599077213161],
#                 {}
#             ).addTo(map_d1ff0a4275f87aa22174214f407e0632);
#
#
#             var icon_688af173f5ab7326c8fa8d64b4eb478e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3eac4957ce6f10dda577e427a0f5df6d.setIcon(icon_688af173f5ab7326c8fa8d64b4eb478e);
#
#
#         var popup_a43e24952167d171f28645de7b671e17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e4b5e1a6872b9f34b2f5fbb76c7bbe2 = $(`&lt;div id=&quot;html_4e4b5e1a6872b9f34b2f5fbb76c7bbe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;下川入&lt;/div&gt;`)[0];
#                 popup_a43e24952167d171f28645de7b671e17.setContent(html_4e4b5e1a6872b9f34b2f5fbb76c7bbe2);
#
#
#
#         marker_3eac4957ce6f10dda577e427a0f5df6d.bindPopup(popup_a43e24952167d171f28645de7b671e17)
#         ;
#
#
#
#
#             var marker_749ad131d33892e9239f23c667695c48 = L.marker(
#                 [35.49687634897616, 139.34302500822187],
#                 {}
#             ).addTo(map_d1ff0a4275f87aa22174214f407e0632);
#
#
#             var icon_4c3a3c225fc93f779cd348934f542e3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_749ad131d33892e9239f23c667695c48.setIcon(icon_4c3a3c225fc93f779cd348934f542e3a);
#
#
#         var popup_fdef4bbbb13f395c22f454e0ec5d75ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd0aef1bca370ad858fdf9593d78228c = $(`&lt;div id=&quot;html_cd0aef1bca370ad858fdf9593d78228c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;才戸橋&lt;/div&gt;`)[0];
#                 popup_fdef4bbbb13f395c22f454e0ec5d75ff.setContent(html_cd0aef1bca370ad858fdf9593d78228c);
#
#
#
#         marker_749ad131d33892e9239f23c667695c48.bindPopup(popup_fdef4bbbb13f395c22f454e0ec5d75ff)
#         ;
#
#
#
#
#             var marker_317ed8bd5bc53ca274d7e30c35c329e5 = L.marker(
#                 [35.49662577303927, 139.31543551468644],
#                 {}
#             ).addTo(map_d1ff0a4275f87aa22174214f407e0632);
#
#
#             var icon_421efd76df3fa5513975b42fbeb87dca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_317ed8bd5bc53ca274d7e30c35c329e5.setIcon(icon_421efd76df3fa5513975b42fbeb87dca);
#
#
#         var popup_8776e83c2be997d03b9dbdf99964728d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c223096a57ba61c21491b1c14d9baef7 = $(`&lt;div id=&quot;html_c223096a57ba61c21491b1c14d9baef7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;久保&lt;/div&gt;`)[0];
#                 popup_8776e83c2be997d03b9dbdf99964728d.setContent(html_c223096a57ba61c21491b1c14d9baef7);
#
#
#
#         marker_317ed8bd5bc53ca274d7e30c35c329e5.bindPopup(popup_8776e83c2be997d03b9dbdf99964728d)
#         ;
#
#
#
#
#             var marker_fada8d8267d31b0febacbcc9992be19e = L.marker(
#                 [35.495061215065974, 139.34039997472757],
#                 {}
#             ).addTo(map_d1ff0a4275f87aa22174214f407e0632);
#
#
#             var icon_c76a16d1875b6cbca89985913a1a5544 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;inf
